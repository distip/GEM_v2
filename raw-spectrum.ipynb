# %%
import pandas as pd
import numpy as np

# %%
file_name = 'Deniz_Han_Part-II'

# %%
read_file = pd.read_csv(file_name +'.txt', low_memory=False)
read_file.to_csv(file_name + '.csv')

# %%
data = pd.read_csv(file_name + '.csv', low_memory=False)

# %%
data.drop(index=data.index[0:32], axis = 0, inplace=True)

# %%
data.drop(columns='Unnamed: 0', axis=1, inplace=True)

# %%
data.columns = data.iloc[0]

# %%
data.to_csv(file_name + '.csv')

# %%
data
# Out:
# 32    Wavelength  \
# 32    Wavelength
# 33           350
# 34           351
# 35           352
# 36           353
# ...          ...
# 2179        2496
# 2180        2497
# 2181        2498
# 2182        2499
# 2183        2500
#
# 32   \Users\Deniz\Desktop\2022-raw spectrums\Deniz-2022-BrookeandAlliance\3306$HN1.asd  \
# 32    \Users\Deniz\Desktop\2022-raw spectrums\Deniz-...
# 33                                 2.91751193993153E-02
# 34                                    0.033590950901731
# 35                                 3.27903205384077E-02
# 36                                 2.61019509584825E-02
# ...                                                 ...
# 2179                               4.15257655408366E-02
# 2180                               4.15474307394703E-02
# 2181                               4.18087884524377E-02
# 2182                               4.14555172306896E-02
# 2183                               4.14427060297861E-02
#
# ...
