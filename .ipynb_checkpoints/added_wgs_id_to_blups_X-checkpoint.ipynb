# %%
import pandas as pd

# %%
blups = pd.read_csv('blups_CHL.csv')

# %%
ids = pd.read_csv('BGEM_WGS_Labels.csv')

# %%
GWAS_labels.columns
# Out:
# Index(['UID'], dtype='object')

# %%
GWAS_labels = pd.read_csv('WGS_labels_only.csv')

# %%
GWAS_labels.rename(columns={'UID                     ': 'UID'}, inplace=True)

# %%
GWAS_labels['UID'] = GWAS_labels['UID'].str.replace(' ' , '')

# %%
ids = ids.loc[: , ['UID', 'Genotype']]

# %%
ids.rename(columns ={'Genotype': 'genotype'}, inplace=True)

# %%
merged = pd.merge(ids, blups, on='genotype', how='inner')

# %%
merged = pd.merge(merged, GWAS_labels, on='UID', how='inner')

# %%
merged
# Out:
#       UID     genotype         new_GID  PLOT.ID  rows  ranges  Block  Rep Trt  \
# 0    B001  BGEM-0001-N  BGEM-0001-N_HN     4338    38       7      1    2  HN
# 1    B001  BGEM-0001-N  BGEM-0001-N_LN     3151     1       4      1    2  LN
# 2    B002  BGEM-0002-N  BGEM-0002-N_HN     4339    39       7      4    2  HN
# 3    B002  BGEM-0002-N  BGEM-0002-N_LN     3152     2       4      1    2  LN
# 4    B003  BGEM-0003-N  BGEM-0003-N_HN     4136    36       3      4    2  HN
# ..    ...          ...             ...      ...   ...     ...    ...  ...  ..
# 439  B313  BGEM-0251-S  BGEM-0251-S_LN     3124    24       3      2    2  LN
# 440  B314  BGEM-0189-S  BGEM-0189-S_HN     4290    40       6      3    2  HN
# 441  B314  BGEM-0189-S  BGEM-0189-S_LN     3103     3       3      2    2  LN
# 442  B315  BGEM-0249-N  BGEM-0249-N_HN     4002     2       1      3    2  HN
# 443  B315  BGEM-0249-N  BGEM-0249-N_LN     3027    27       1      2    2  LN
#
#      year             note   Group  Calibration  ASD         CHL
# 0    2022  BGEM_Tall_early  Inbred          0.0  2.0  291.162515
# 1    2022  BGEM_Tall_early  Inbred          0.0  2.0  290.635128
# 2    2022  BGEM_Tall_early  Inbred          0.0  2.0  382.761990
# 3    2022  BGEM_Tall_early  Inbred          0.0  2.0  304.242242
# 4    2022   BGEM_Tall_late  Inbred          0.0  1.0  413.810227
# ..    ...              ...     ...          ...  ...         ...
# 439  2022  BGEM_Tall_early  Inbred          0.0  1.0  354.588511
# 440  2022  BGEM_Tall_early  Inbred          0.0  2.0  309.041145
# 441  2022  BGEM_Tall_early  Inbred          0.0  2.0  287.311513
# 442  2022  BGEM_Short_late  Inbred          0.0  2.0  354.627108
# 443  2022  BGEM_Short_late  Inbred          0.0  2.0  325.302650
#
# [444 rows x 15 columns]

# %%
merged.to_csv('blups_CHL_with_gwas_ids')

# %% [markdown]
# # adding uids to CHL blues

# %%
import pandas as pd
blues = pd.read_csv('blues_CHL.csv')

# %%
ids = pd.read_csv('BGEM_WGS_Labels.csv')

# %%
GWAS_labels = pd.read_csv('WGS_labels_only.csv')

# %%
GWAS_labels.columns
# Out:
# Index(['UID                     '], dtype='object')

# %%
GWAS_labels.rename(columns={'UID                     ': 'UID'}, inplace=True)

# %%
GWAS_labels['UID'] = GWAS_labels['UID'].str.replace(' ' , '')

# %%
ids = ids.loc[: , ['UID', 'Genotype']]

# %%
ids.rename(columns ={'Genotype': 'genotype'}, inplace=True)

# %%
merged = pd.merge(ids, blues, on='genotype', how='inner')

# %%
merged = pd.merge(merged, GWAS_labels, on='UID', how='inner')

# %%
merged[150:200]
# Out:
#       UID     genotype         CHL
# 150  B181  BGEM-0218-S  416.263150
# 151  B182  BGEM-0219-S  416.209626
# 152  B183  BGEM-0220-S  412.559094
# 153  B185  BGEM-0222-S  352.596482
# 154  B186  BGEM-0223-N  329.128886
# 155  B187  BGEM-0224-N  330.930843
# 156  B188  BGEM-0225-N  340.939306
# 157  B189  BGEM-0226-S  393.894184
# 158  B190  BGEM-0227-N  336.101404
# 159  B191  BGEM-0228-N  343.753798
# 160  B194  BGEM-0231-N  305.845625
# 161  B195  BGEM-0233-S  370.878558
# 162  B197  BGEM-0236-S  363.605298
# 163  B198  BGEM-0237-N  352.422402
# 164  B201  BGEM-0242-N  443.588872
# 165  B202  BGEM-0243-S  446.065473
# 166  B204  BGEM-0246-N  315.993764
# 167  B205  BGEM-0247-N  314.024276
# 168  B206  BGEM-0248-N  418.097920
# 169  B207  BGEM-0250-S  364.778382
# 170  B209  BGEM-0252-S  365.171412
# 171  B210  BGEM-0253-N  358.046540
# 172  B211  BGEM-0254-S  372.546039
# 173  B212  BGEM-0255-S  325.351553
# 174  B214  BGEM-0257-S  325.069733
# 175  B215  BGEM-0258-S  376.550860
# 176  B225  BGEM-0270-S  372.321754
# 177  B226  BGEM-0272-S  425.098623
# 178  B231  BGEM-0280-S  396.677786
# 179  B236  BGEM-0285-N  326.663133
# 180  B238  BGEM-0287-N  346.954765
# 181  B239  BGEM-0288-S  357.530833
# 182  B243  BGEM-0292-S  352.739455
# 183  B246  BGEM-0295-S  388.117605
# 184  B247  BGEM-0296-S  434.780416
# 185  B248  BGEM-0297-N  387.700854
# 186  B251  BGEM-0300-S  312.084725
# 187  B252  BGEM-0301-S  266.328127
# 188  B254  BGEM-0302-S  368.238593
# 189  B257  BGEM-0305-S  323.115697
# 190  B259  BGEM-0307-S  380.853856
# 191  B261  BGEM-0309-S  356.567967
# 192  B262  BGEM-0310-S  426.785368
# 193  B265  BGEM-0313-S  386.863081
# 194  B267  BGEM-0315-S  430.969714
# 195  B268  BGEM-0316-S  316.940655
# 196  B273  BGEM-0321-S  404.557495
# 197  B274  BGEM-0322-S  363.763797
# 198  B276  BGEM-0324-N  328.841376
# 199  B277  BGEM-0325-N  377.985110
