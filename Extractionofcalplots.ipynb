# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Raw_spectrum_merged')

# %%
data.head()
# Out:
#    Unnamed: 0  PLOT ID  Block  Rep Trt  year     genotype            note  \
# 0           0     1001      1    1  HN  2022  BGEM-0312-S  BGEM_Tall_late
# 1           1     1002      1    1  HN  2022  BGEM-0245-S  BGEM_Tall_late
# 2           2     1003      1    1  HN  2022  BGEM-0292-S  BGEM_Tall_late
# 3           3     1004      1    1  HN  2022  BGEM-0075-S  BGEM_Tall_late
# 4           4     1005      1    1  HN  2022  BGEM-0204-N  BGEM_Tall_late
#
#    Calibration  ASD  ...      2491      2492      2493      2494      2495  \
# 0          0.0  2.0  ...  0.035234  0.035088  0.034933  0.034826  0.034614
# 1          0.0  2.0  ...  0.037554  0.037249  0.037154  0.037163  0.037074
# 2          0.0  2.0  ...  0.042723  0.042242  0.042083  0.041943  0.041776
# 3          0.0  1.0  ...  0.041980  0.041998  0.041733  0.041467  0.041499
# 4          0.0  1.0  ...  0.035746  0.035719  0.035662  0.035373  0.035116
#
#        2496      2497      2498      2499      2500
# ...

# %%
calib = data.dropna(axis=0).loc[(data['ASD'] != 1) & (data['ASD'] != 2), :]

# %%
calib
# Out:
#       Unnamed: 0  PLOT ID  Block  Rep Trt  year            genotype  \
# 232          232     1233      1    1  HN  2022         BGEM-0035-S
# 233          233     1234      1    1  HN  2022         BGEM-0269-S
# 536          536     1537      1    1  HN  2022  BGEM-0084-S X Mo17
# 545          545     1546      1    1  HN  2022  BGEM-0159-S X Mo17
# 546          546     1547      1    1  HN  2022  BGEM-0251-S X Mo17
# 563          563     1564      1    1  HN  2022  BGEM-0137-S X Mo17
# 592          592     1593      1    1  HN  2022  BGEM-0048-S X Mo17
# 595          595     1596      1    1  HN  2022        LH74 X LH123
# 596          596     1597      1    1  HN  2022        PHG86 x LHB2
# 604          604     2005      2    1  LN  2022         BGEM-0140-N
# 645          645     2046      2    1  LN  2022         BGEM-0239-N
# 646          646     2047      2    1  LN  2022         BGEM-0325-N
# 950          950     2351      2    1  LN  2022       PHJ40 x PHK29
# ...

# %%
ASD_1 = pd.read_csv('ASD_1', low_memory = False)
ASD_2 = pd.read_csv('ASD_2', low_memory= False)

# %%
ASD_1_cals = []
for i in ASD_1['PLOT ID']:
    if '-C' in i:
        ASD_1_cals.append(i)

# %%
ASD_2_cals = []
for i in ASD_2['PLOT ID']:
    if '-C' in i:
        ASD_2_cals.append(i)

# %%
ASD_2_cals
# Out:
# ['1233-C',
#  '1233-C',
#  '1233-C',
#  '1234-C',
#  '1234-C',
#  '1234-C',
#  '1537-C',
#  '1537-C',
#  '1537-C',
#  '1546-C',
#  '1546-C',
#  '1546-C',
#  '1547-C',
#  '1547-C',
#  '1564-C',
#  '1564-C',
#  '1564-C',
#  '1593-C',
#  '1593-C',
#  '1593-C',
#  '1596-C',
#  '1596-C',
#  '1596-C',
#  '1597-C',
#  '1597-C',
#  '1597-C',
#  '2005-C',
#  '2046-C',
#  '2046-C',
#  '2046-C',
#  '2047-C',
#  '2047-C',
#  '2047-C',
#  '2351-C',
#  '2351-C',
#  '2351-C',
#  '2352-C',
#  '2352-C',
#  '2352-C',
#  '2354-C',
#  '2354-C',
#  '2354-C',
#  '2355-C',
#  '2355-C',
#  '2355-C',
#  '2357-C',
#  '2357-C',
#  '2357-C',
#  '2375-C',
#  '2375-C',
#  '2375-C',
#  '3161-C',
#  '3161-C',
#  '3161-C',
#  '3168-C',
#  '3168-C',
#  '3168-C',
#  '3169-C',
#  '3169-C',
#  '3169-C',
#  '3480-C',
#  '3480-C',
#  '3480-C',
#  '3481-C',
#  '3481-C',
#  '3481-C',
#  '3482-C',
#  '3482-C',
#  '3482-C',
#  '3483-C',
#  '3483-C',
#  '3483-C',
#  '3484-C',
#  '3484-C',
#  '3484-C',
#  '3577-C',
# ...

# %%
ASD_1_cal_spec = ASD_1.loc[ASD_1['PLOT ID'].isin(ASD_1_cals) , :]

# %%
ASD_2_cal_spec = ASD_2.loc[ASD_2['PLOT ID'].isin(ASD_2_cals) , :]

# %%
ASD_1_cal_spec.shape
# Out:
# (116, 2154)

# %%
ASD_2_cal_spec.shape
# Out:
# (111, 2154)

# %%
ASD_2_cal_spec
# Out:
#       Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 331          334  1233-C    2  0.105390  0.087285  0.087096  0.099172
# 332          335  1233-C    2  0.094365  0.079207  0.071710  0.076381
# 333          336  1233-C    2  0.108844  0.095919  0.091865  0.092696
# 334          337  1234-C    2  0.112791  0.123914  0.115442  0.101943
# 335          338  1234-C    2  0.094505  0.059541  0.056669  0.076689
# ...          ...     ...  ...       ...       ...       ...       ...
# 3317        3403  4499-C    2  0.067264  0.078679  0.093325  0.113042
# 3318        3404  4499-C    2  0.077433  0.100201  0.128690  0.134658
# 3400        3492  4580-C    2  0.082168  0.096496  0.106282  0.112701
# 3401        3493  4580-C    2  0.082400  0.102238  0.114614  0.111467
# 3402        3494  4580-C    2  0.093213  0.098944  0.101784  0.109335
#
#            354       355       356  ...      2491      2492      2493  \
# ...

# %%
calibration = pd.concat([ASD_1_cal_spec, ASD_2_cal_spec])

# %%
calibration.loc[calibration['PLOT ID'] == '1233-C']
# Out:
#      Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 354         363  1233-C    1  0.060566  0.052464  0.052242  0.059931
# 355         364  1233-C    1  0.054275  0.048762  0.044083  0.044622
# 356         365  1233-C    1  0.057250  0.059248  0.058277  0.054839
# 331         334  1233-C    2  0.105390  0.087285  0.087096  0.099172
# 332         335  1233-C    2  0.094365  0.079207  0.071710  0.076381
# 333         336  1233-C    2  0.108844  0.095919  0.091865  0.092696
#
#           354       355       356  ...      2491      2492      2493  \
# 354  0.056733  0.054029  0.051552  ...  0.056058  0.056105  0.056258
# 355  0.047741  0.043943  0.038749  ...  0.057884  0.057869  0.057625
# 356  0.052193  0.047101  0.046472  ...  0.067326  0.067209  0.067080
# 331  0.098385  0.082395  0.075764  ...  0.039352  0.039088  0.038925
# 332  0.084414  0.084296  0.083687  ...  0.039194  0.038931  0.038778
# ...

# %%
calibration.head()
# Out:
#      Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 354         363  1233-C    1  0.060566  0.052464  0.052242  0.059931
# 355         364  1233-C    1  0.054275  0.048762  0.044083  0.044622
# 356         365  1233-C    1  0.057250  0.059248  0.058277  0.054839
# 357         366  1234-C    1  0.036413  0.043467  0.047815  0.046696
# 358         367  1234-C    1  0.045392  0.049335  0.049849  0.045932
#
#           354       355       356  ...      2491      2492      2493  \
# 354  0.056733  0.054029  0.051552  ...  0.056058  0.056105  0.056258
# 355  0.047741  0.043943  0.038749  ...  0.057884  0.057869  0.057625
# 356  0.052193  0.047101  0.046472  ...  0.067326  0.067209  0.067080
# 357  0.047002  0.041791  0.036547  ...  0.048853  0.048603  0.048908
# 358  0.052923  0.048324  0.040895  ...  0.048891  0.049083  0.049320
#
#          2494      2495      2496      2497      2498      2499      2500
# ...

# %%
ids = []
for i in calibration['PLOT ID']:
    a=i[0:4]
    ids.append(a)

# %%
calibration.drop('PLOT ID', axis=1, inplace= True)

# %%
calibration.insert(1, 'PLOT ID', ids)

# %%
calibration.drop('Unnamed: 0', axis=1 , inplace=True)

# %%
calibration.head(20)
# Out:
#     PLOT ID  ASD       350       351       352       353       354       355  \
# 354    1233    1  0.060566  0.052464  0.052242  0.059931  0.056733  0.054029
# 355    1233    1  0.054275  0.048762  0.044083  0.044622  0.047741  0.043943
# 356    1233    1  0.057250  0.059248  0.058277  0.054839  0.052193  0.047101
# 357    1234    1  0.036413  0.043467  0.047815  0.046696  0.047002  0.041791
# 358    1234    1  0.045392  0.049335  0.049849  0.045932  0.052923  0.048324
# 359    1234    1  0.070732  0.064516  0.055882  0.057374  0.064428  0.058125
# 855    1537    1  0.056939  0.051314  0.045492  0.042975  0.042529  0.041653
# 856    1537    1  0.065501  0.054829  0.047012  0.051753  0.049786  0.047819
# 857    1537    1  0.054831  0.056688  0.050731  0.040445  0.048388  0.053269
# 867    1546    1  0.060453  0.054039  0.050739  0.053106  0.057916  0.058834
# 868    1546    1  0.054487  0.052103  0.051068  0.051285  0.052276  0.054006
# ...

# %%
cal1 = calibration.loc[calibration['ASD'] == 1, :].groupby('PLOT ID', as_index = False).mean()

# %%
cal2 = calibration.loc[calibration['ASD'] == 2, :].groupby('PLOT ID', as_index=False).mean()

# %%
calibration_v2= pd.concat([cal1, cal2], join = 'outer')

# %%
calibration_v2.head()
# Out:
#   PLOT ID  ASD       350       351       352       353       354       355  \
# 0    1233    1  0.057364  0.053491  0.051534  0.053131  0.052223  0.048358
# 1    1234    1  0.050846  0.052439  0.051182  0.050001  0.054784  0.049413
# 2    1537    1  0.059090  0.054277  0.047745  0.045058  0.046901  0.047580
# 3    1546    1  0.056725  0.052486  0.050089  0.051583  0.053778  0.053886
# 4    1547    1  0.061166  0.059794  0.054349  0.048403  0.052049  0.052484
#
#         356       357  ...      2491      2492      2493      2494      2495  \
# 0  0.045591  0.047290  ...  0.060423  0.060394  0.060321  0.060078  0.059742
# 1  0.042845  0.045247  ...  0.053574  0.053545  0.053710  0.053496  0.053215
# 2  0.048036  0.050105  ...  0.051938  0.051765  0.051664  0.051613  0.051517
# 3  0.051979  0.049963  ...  0.057990  0.057604  0.057202  0.056947  0.057195
# 4  0.050083  0.048816  ...  0.061234  0.061182  0.060936  0.060705  0.060563
#
#        2496      2497      2498      2499      2500
# ...

# %%
calibration_v2.to_csv('calibration')

# %%
PLOT_ID = []
for i in ASD_1_cal_spec['PLOT ID']: 
    PLOT_ID.append(i[0:4])

# %%
ASD_1_cal_spec['PLOT ID'] = PLOT_ID
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ASD_1_cal_spec.drop('Unnamed: 0' , axis=1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ASD_1_cal_spec.drop('PLOT ID' , axis=1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ASD_1_cal_spec.drop('ASD' , axis=1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ASD_2_cal_spec.loc[ASD_2_cal_spec['900'] < 0.4 , :]
# Out:
#      Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 767         768  1547-C    2  0.041468  0.010695 -0.005133  0.006563
#
#           354       355       356  ...      2491      2492      2493  \
# 767  0.013354  0.026106  0.015554  ...  0.001233  0.001071  0.001042
#
#          2494      2495      2496      2497      2498      2499      2500
# 767  0.000813  0.000874  0.001415  0.001475  0.001407  0.001278  0.000701
#
# [1 rows x 2154 columns]

# %%
ASD_2_cal_spec.loc[ASD_2_cal_spec['900'] > 0.52 , :]
# Out:
#      Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 846         847  2005-C    2  0.140497  0.127302  0.133939  0.140938
# 847         848  2005-C    2  0.153367  0.132711  0.118651  0.120548
#
#           354       355       356  ...      2491      2492      2493  \
# 846  0.118913  0.117346  0.121790  ...  0.070306  0.070101  0.069901
# 847  0.135404  0.133438  0.123233  ...  0.070346  0.069996  0.069530
#
#          2494      2495      2496      2497      2498      2499      2500
# 846  0.068763  0.068466  0.069648  0.069575  0.068554  0.068448  0.068394
# 847  0.068321  0.068028  0.068474  0.068400  0.068671  0.068649  0.068042
#
# [2 rows x 2154 columns]

# %%
ASD_2_cal_spec.loc[ASD_2_cal_spec['PLOT ID'] == '1547-C' , :]
# Out:
#      Unnamed: 0 PLOT ID  ASD       350       351       352       353  \
# 765         766  1547-C    2  0.067111  0.078288  0.081066  0.078109
# 766         767  1547-C    2  0.120727  0.094408  0.087622  0.095548
# 767         768  1547-C    2  0.041468  0.010695 -0.005133  0.006563
#
#           354       355       356  ...      2491      2492      2493  \
# 765  0.095855  0.091755  0.077709  ...  0.033364  0.032889  0.032685
# 766  0.086669  0.096958  0.098390  ...  0.037088  0.036686  0.036478
# 767  0.013354  0.026106  0.015554  ...  0.001233  0.001071  0.001042
#
#          2494      2495      2496      2497      2498      2499      2500
# 765  0.032340  0.032013  0.031848  0.031707  0.031333  0.031301  0.031907
# 766  0.036519  0.036441  0.036332  0.036358  0.036732  0.036398  0.035464
# 767  0.000813  0.000874  0.001415  0.001475  0.001407  0.001278  0.000701
#
# [3 rows x 2154 columns]

# %%
PLOT_ID_2 = []
for i in ASD_2_cal_spec['PLOT ID']: 
    PLOT_ID_2.append(i[0:4])

# %%
ASD_2_cal_spec['PLOT ID'] = PLOT_ID_2
ASD_2_cal_spec.drop('Unnamed: 0' , axis=1, inplace = True)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
ASD_2_cal_spec.drop(['PLOT ID', 'ASD'] , axis=1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
plt.plot(ASD_1_cal_spec.T, color= 'r')
plt.plot(ASD_2_cal_spec.T, color= 'g')
plt.legend()
plt.xticks(ticks=['450', '700', '900', '1500', '2000', '2500'])
plt.xlabel('Wavelength')
plt.ylabel('Reflectance')
# Out:
# No handles with labels found to put in legend.
# Text(0, 0.5, 'Reflectance')
