# %%
import pandas as pd
import numpy as np

# %%
spectrum = pd.read_csv('Raw_spectrum_merged')

# %%
spectrum[10:50]
# Out:
#     PLOT ID  rows  ranges  Block  Rep Trt  year     genotype  \
# 10     1011    11       1      1    1  HN  2022  BGEM-0103-N
# 11     1012    12       1      1    1  HN  2022  BGEM-0308-S
# 12     1013    13       1      1    1  HN  2022  BGEM-0231-N
# 13     1014    14       1      1    1  HN  2022  BGEM-0210-N
# 14     1015    15       1      1    1  HN  2022  BGEM-0065-N
# 15     1016    16       1      1    1  HN  2022         Mo17
# 16     1017    17       1      1    1  HN  2022  BGEM-0178-S
# 17     1018    18       1      1    1  HN  2022  BGEM-0106-N
# 18     1019    19       1      1    1  HN  2022  BGEM-0069-S
# 19     1020    20       1      1    1  HN  2022  BGEM-0043-S
# 20     1021    21       1      1    1  HN  2022  BGEM-0239-N
# 21     1022    22       1      1    1  HN  2022  BGEM-0325-N
# 22     1023    23       1      1    1  HN  2022  BGEM-0290-N
# 23     1024    24       1      1    1  HN  2022          B73
# ...

# %%
spectrum.drop(spectrum.filter(regex='Unname'), axis=1 , inplace=True)

# %%
spectrum['genotype'] = spectrum['genotype'].str.replace(' x ', ' X ')

# %%
spectrum['genotype'] = spectrum['genotype'].str.replace('MO17', 'Mo17')

# %%
note = []
for i in spectrum['genotype'] :
    if ' X ' in i:
        note.append('Hybrid')
    else:
        note.append('Inbred')

# %%
spectrum.drop(labels='note', axis=1, inplace=True)

# %%
spectrum.insert(8, 'note', note)

# %%
spectrum.loc[spectrum['2491'].notnull(), :]
# Out:
#       Unnamed: 0  PLOT ID  rows  ranges  Block  Rep Trt  year     genotype  \
# 0              0     1001     1       1      1    1  HN  2022  BGEM-0312-S
# 1              1     1002     2       1      1    1  HN  2022  BGEM-0245-S
# 2              2     1003     3       1      1    1  HN  2022  BGEM-0292-S
# 3              3     1004     4       1      1    1  HN  2022  BGEM-0075-S
# 4              4     1005     5       1      1    1  HN  2022  BGEM-0204-N
# ...          ...      ...   ...     ...    ...  ...  ..   ...          ...
# 2395        2395     4596    46      12      4    2  HN  2022   B73 X Mo17
# 2396        2396     4597    47      12      4    2  HN  2022   B73 X Mo17
# 2397        2397     4598    48      12      4    2  HN  2022   B73 X Mo17
# 2398        2398     4599    49      12      4    2  HN  2022   B73 X Mo17
# 2399        2399     4600    50      12      4    2  HN  2022   B73 X Mo17
#
# ...

# %%
field_layout = pd.read_csv('field_book.csv')

# %%
note2 =field_layout['note']

# %%
spectrum.rename(columns={'note': 'Group'},inplace=True)

# %%
spectrum.insert(9, 'note', note2)

# %%
spectrum.head()
# Out:
#    Unnamed: 0  PLOT ID  rows  ranges  Block  Rep Trt  year     genotype  \
# 0           0     1001     1       1      1    1  HN  2022  BGEM-0312-S
# 1           1     1002     2       1      1    1  HN  2022  BGEM-0245-S
# 2           2     1003     3       1      1    1  HN  2022  BGEM-0292-S
# 3           3     1004     4       1      1    1  HN  2022  BGEM-0075-S
# 4           4     1005     5       1      1    1  HN  2022  BGEM-0204-N
#
#              note  ...      2491      2492      2493      2494      2495  \
# 0  BGEM_Tall_late  ...  0.035234  0.035088  0.034933  0.034826  0.034614
# 1  BGEM_Tall_late  ...  0.037554  0.037249  0.037154  0.037163  0.037074
# 2  BGEM_Tall_late  ...  0.042723  0.042242  0.042083  0.041943  0.041776
# 3  BGEM_Tall_late  ...  0.041980  0.041998  0.041733  0.041467  0.041499
# 4  BGEM_Tall_late  ...  0.035746  0.035719  0.035662  0.035373  0.035116
#
#        2496      2497      2498      2499      2500
# ...

# %%
spectrum.to_csv('Raw_spectrum_merged')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aea3bd2cd1fa> in <module>()
# ----> 1 spectrum.to_csv('Raw_spectrum_merged')
#
# NameError: name 'spectrum' is not defined
